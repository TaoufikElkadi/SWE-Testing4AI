# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix

# Load models and data
with open('../models/good_model.pkl', 'rb') as f:
    good_model = pickle.load(f)
with open('../models/bad_model.pkl', 'rb') as f:
    bad_model = pickle.load(f)
with open('../data/test_data.pkl', 'rb') as f:
    test_data = pickle.load(f)

X_test = test_data['X_test']
y_test = test_data['y_test']

def analyze_errors(model, X, y):
    """Analyze prediction errors and patterns"""
    y_pred = model.predict(X)
    conf_matrix = confusion_matrix(y, y_pred)
    
    error_analysis = {
        'confusion_matrix': conf_matrix,
        'error_patterns': {},
        'feature_importance': {}
    }
    
    # Analyze where errors occur most
    errors_mask = y_pred != y
    for col in X.columns:
        # Calculate error rate by feature value
        value_errors = pd.DataFrame({
            'value': X[col],
            'is_error': errors_mask
        }).groupby('value')['is_error'].mean()
        
        error_analysis['error_patterns'][col] = value_errors.nlargest(3).to_dict()
        
    # Feature importance in errors
    feature_importance = model.named_steps['classifier'].feature_importances_
    error_analysis['feature_importance'] = dict(zip(X.columns, feature_importance))
    
    return error_analysis

# Run evaluation for both models
models = {'Good': good_model, 'Bad': bad_model}

for name, model in models.items():
    print(f"\n{'='*20} {name} Model {'='*20}")
    y_pred = model.predict(X_test)
    
    # Basic metrics
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))
    
    # Error analysis
    error_results = analyze_errors(model, X_test, y_test)
    conf_matrix = error_results['confusion_matrix']
    
    print("\nConfusion Matrix:")
    print(conf_matrix)
    
    print("\nError Patterns:")
    for feature, patterns in error_results['error_patterns'].items():
        if any(rate > 0.3 for rate in patterns.values()):  # Only show significant patterns
            print(f"\n{feature}:")
            for value, error_rate in patterns.items():
                print(f"  Value {value:.2f}: {error_rate:.2%} error rate")
    
    print("\nTop 5 Most Important Features:")
    importances = error_results['feature_importance']
    for feature, importance in sorted(importances.items(), key=lambda x: x[1], reverse=True)[:5]:
        print(f"  {feature}: {importance:.3f}")
# Out:
# ==================== Good Model ====================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.87      1.00      0.93     22029
#         True       0.98      0.16      0.27      3971
#
#     accuracy                           0.87     26000
#    macro avg       0.92      0.58      0.60     26000
# weighted avg       0.89      0.87      0.83     26000
#
#
# Confusion Matrix:
# [[22017    12]
#  [ 3341   630]]
#
# Error Patterns:
#
# adres_aantal_brp_adres:
#   Value 11.00: 50.00% error rate
#   Value 10.00: 40.00% error rate
#   Value 8.00: 27.35% error rate
#
# adres_aantal_verschillende_wijken:
#   Value 7.00: 50.00% error rate
#   Value 6.00: 22.22% error rate
#   Value 5.00: 18.31% error rate
#
# adres_dagen_op_adres:
#   Value 5.00: 100.00% error rate
#   Value 13.00: 100.00% error rate
#   Value 14.00: 100.00% error rate
#
# afspraak_aantal_woorden:
#   Value 736.00: 100.00% error rate
#   Value 760.00: 100.00% error rate
#   Value 772.00: 100.00% error rate
#
# afspraak_laatstejaar_aantal_woorden:
#   Value 315.00: 100.00% error rate
#   Value 369.00: 100.00% error rate
#   Value 319.00: 60.00% error rate
#
# afspraak_laatstejaar_resultaat_ingevuld:
#   Value 10.00: 100.00% error rate
#   Value 8.00: 35.29% error rate
#   Value 7.00: 20.31% error rate
#
# afspraak_resultaat_ingevuld_uniek:
#   Value 7.00: 30.71% error rate
#   Value 9.00: 25.00% error rate
#   Value 6.00: 20.99% error rate
#
# afspraak_voortgangsgesprek:
#   Value 5.00: 66.67% error rate
#   Value 4.00: 19.35% error rate
#   Value 3.00: 15.35% error rate
#
# belemmering_aantal_huidig:
#   Value 8.00: 50.00% error rate
#   Value 5.00: 17.30% error rate
#   Value 6.00: 16.28% error rate
#
# belemmering_dagen_financiele_problemen:
#   Value -11248.00: 100.00% error rate
#   Value -9449.00: 100.00% error rate
#   Value -9292.00: 100.00% error rate
#
# belemmering_dagen_lichamelijke_problematiek:
#   Value -15319.00: 100.00% error rate
#   Value -15233.00: 100.00% error rate
#   Value -15221.00: 100.00% error rate
#
# belemmering_dagen_psychische_problemen:
#   Value -35893.00: 100.00% error rate
#   Value -32015.00: 100.00% error rate
#   Value -32007.00: 100.00% error rate
#
# competentie_aansturen:
#   Value 2.00: 30.19% error rate
#   Value 1.00: 15.47% error rate
#   Value 0.00: 11.75% error rate
#
# competentie_gedrevenheid_en_ambitie_tonen:
#   Value 2.00: 100.00% error rate
#   Value 1.00: 16.11% error rate
#   Value 0.00: 12.26% error rate
#
# competentie_leren:
#   Value 2.00: 100.00% error rate
#   Value 1.00: 15.17% error rate
#   Value 0.00: 12.48% error rate
#
# contacten_onderwerp_inname_aanvraag:
#   Value 2.00: 100.00% error rate
#   Value 1.00: 15.88% error rate
#   Value 0.00: 12.21% error rate
#
# contacten_onderwerp_inspanningstoets:
#   Value 3.00: 40.00% error rate
#   Value 2.00: 23.31% error rate
#   Value 1.00: 15.28% error rate
#
# contacten_onderwerp_maatregel_overweging:
#   Value 3.00: 50.00% error rate
#   Value 2.00: 18.52% error rate
#   Value 1.00: 14.57% error rate
#
# contacten_onderwerp_matching:
#   Value 16.00: 100.00% error rate
#   Value 15.00: 80.00% error rate
#   Value 14.00: 33.33% error rate
#
# contacten_onderwerp_no_show:
#   Value 5.00: 45.00% error rate
#   Value 4.00: 26.64% error rate
#   Value 3.00: 24.17% error rate
#
# contacten_onderwerp_overige:
#   Value 30.00: 33.33% error rate
#   Value 26.00: 26.09% error rate
#   Value 21.00: 21.19% error rate
#
# contacten_onderwerp_traject:
#   Value 29.00: 33.33% error rate
#   Value 27.00: 25.00% error rate
#   Value 23.00: 20.00% error rate
#
# contacten_onderwerp_uitnodiging:
#   Value 7.00: 33.33% error rate
#   Value 4.00: 18.13% error rate
#   Value 5.00: 17.73% error rate
#
# contacten_onderwerp_ziek__of_afmelding:
#   Value 7.00: 44.44% error rate
#   Value 6.00: 19.13% error rate
#   Value 5.00: 17.17% error rate
#
# contacten_soort_afgelopenjaar_anders:
#   Value 5.00: 32.35% error rate
#   Value 4.00: 29.02% error rate
#   Value 3.00: 23.10% error rate
#
# contacten_soort_afgelopenjaar_document__inkomend_:
#   Value 8.00: 66.67% error rate
#   Value 6.00: 21.50% error rate
#   Value 5.00: 16.52% error rate
#
# contacten_soort_afgelopenjaar_document__uitgaand_:
#   Value 13.00: 33.64% error rate
#   Value 19.00: 33.33% error rate
#   Value 17.00: 25.00% error rate
#
# contacten_soort_afgelopenjaar_e_mail__inkomend_:
#   Value 8.00: 50.00% error rate
#   Value 6.00: 20.56% error rate
#   Value 7.00: 19.05% error rate
#
# contacten_soort_afgelopenjaar_e_mail__uitgaand_:
#   Value 8.00: 38.46% error rate
#   Value 6.00: 27.65% error rate
#   Value 7.00: 26.53% error rate
#
# contacten_soort_afgelopenjaar_gesprek:
#   Value 7.00: 33.33% error rate
#   Value 6.00: 25.00% error rate
#   Value 5.00: 19.15% error rate
#
# contacten_soort_afgelopenjaar_telefoontje__uitgaand_:
#   Value 8.00: 50.00% error rate
#   Value 6.00: 25.81% error rate
#   Value 5.00: 22.69% error rate
#
# contacten_soort_anders:
#   Value 13.00: 50.00% error rate
#   Value 12.00: 26.09% error rate
#   Value 11.00: 20.75% error rate
#
# contacten_soort_document__uitgaand_:
#   Value 92.00: 100.00% error rate
#   Value 104.00: 100.00% error rate
#   Value 83.00: 50.00% error rate
#
# contacten_soort_e_mail__uitgaand_:
#   Value 23.00: 50.00% error rate
#   Value 24.00: 50.00% error rate
#   Value 22.00: 33.33% error rate
#
# contacten_soort_telefoontje__uitgaand_:
#   Value 20.00: 33.33% error rate
#   Value 19.00: 25.00% error rate
#   Value 15.00: 19.61% error rate
#
# deelname_act_reintegratieladder_werk_re_integratie:
#   Value 18.00: 100.00% error rate
#   Value 19.00: 66.67% error rate
#   Value 21.00: 50.00% error rate
#
# instrument_aantal_laatstejaar:
#   Value 5.00: 37.50% error rate
#   Value 6.00: 33.33% error rate
#   Value 4.00: 21.16% error rate
#
# instrument_ladder_historie_other:
#   Value 4.00: 50.00% error rate
#   Value 2.00: 15.18% error rate
#   Value 1.00: 13.56% error rate
#
# instrument_reden_beeindiging_historie_uitval__klant_wz__ziet_af_van_aanbod:
#   Value 2.00: 33.33% error rate
#   Value 1.00: 15.49% error rate
#   Value 0.00: 12.21% error rate
#
# ontheffing_dagen_hist_mean:
#   Value 133.00: 100.00% error rate
#   Value 151.00: 100.00% error rate
#   Value 153.00: 100.00% error rate
#
# ontheffing_dagen_hist_vanwege_uw_medische_omstandigheden:
#   Value 2.00: 100.00% error rate
#   Value 10.00: 100.00% error rate
#   Value 16.00: 100.00% error rate
#
# persoon_leeftijd_bij_onderzoek:
#   Value 66.00: 51.50% error rate
#   Value 67.00: 39.06% error rate
#   Value 19.00: 37.93% error rate
#
# persoonlijke_eigenschappen_dagen_sinds_opvoer:
#   Value 1266.00: 100.00% error rate
#   Value 1339.00: 100.00% error rate
#   Value 1343.00: 100.00% error rate
#
# persoonlijke_eigenschappen_dagen_sinds_taaleis:
#   Value 1267.00: 100.00% error rate
#   Value 1396.00: 100.00% error rate
#   Value 1501.00: 100.00% error rate
#
# pla_einde_doelstelling_niet_bereikt__nieuw_trajectplan:
#   Value 7.00: 50.00% error rate
#   Value 0.00: 14.17% error rate
#   Value 1.00: 13.27% error rate
#
# pla_einde_uitstroom_anders_dan_volgen_onderwijs__regulier_werk_of_als_zelfstandige:
#   Value 2.00: 50.00% error rate
#   Value 1.00: 18.40% error rate
#   Value 0.00: 11.12% error rate
#
# pla_hist_pla_categorie_doelstelling_11:
#   Value 2.00: 33.33% error rate
#   Value 1.00: 13.26% error rate
#   Value 0.00: 12.78% error rate
#
# relatie_overig_actueel_vorm__kostendeler:
#   Value 5.00: 100.00% error rate
#   Value 4.00: 32.26% error rate
#   Value 3.00: 25.31% error rate
#
# relatie_overig_actueel_vorm__onderhoudsplichtige:
#   Value 2.00: 33.33% error rate
#   Value 1.00: 14.37% error rate
#   Value 0.00: 12.38% error rate
#
# relatie_overig_historie_vorm__kostendeler:
#   Value 6.00: 36.11% error rate
#   Value 5.00: 27.59% error rate
#   Value 4.00: 23.09% error rate
#
# relatie_partner_totaal_dagen_partner:
#   Value 67.00: 100.00% error rate
#   Value 1815.00: 100.00% error rate
#   Value 2493.00: 100.00% error rate
#
# typering_dagen_som:
#   Value -10701.00: 100.00% error rate
#   Value -9473.00: 100.00% error rate
#   Value -8635.00: 100.00% error rate
#
# Top 5 Most Important Features:
#   adres_aantal_verschillende_wijken: 0.058
#   relatie_overig_historie_vorm__onderhoudsplichtige: 0.038
#   afspraak_afgelopen_jaar_afsprakenplan: 0.028
#   relatie_kind_volwassen: 0.025
#   persoonlijke_eigenschappen_nl_begrijpen3: 0.025
#
# ==================== Bad Model ====================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.85      1.00      0.92     22029
#         True       0.00      0.00      0.00      3971
#
#     accuracy                           0.85     26000
#    macro avg       0.42      0.50      0.46     26000
# weighted avg       0.72      0.85      0.78     26000
# c:\Users\Daniel\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Daniel\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Daniel\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Confusion Matrix:
# [[22029     0]
#  [ 3971     0]]
#
# Error Patterns:
#
# adres_aantal_brp_adres:
#   Value 10.00: 60.00% error rate
#   Value 11.00: 50.00% error rate
#   Value 8.00: 33.33% error rate
#
# adres_aantal_verschillende_wijken:
#   Value 7.00: 50.00% error rate
#   Value 6.00: 29.63% error rate
#   Value 5.00: 24.07% error rate
#
# adres_dagen_op_adres:
#   Value 5.00: 100.00% error rate
#   Value 8.00: 100.00% error rate
#   Value 10.00: 100.00% error rate
#
# afspraak_aantal_woorden:
#   Value 736.00: 100.00% error rate
#   Value 760.00: 100.00% error rate
#   Value 772.00: 100.00% error rate
#
# afspraak_controle_aankondiging_maatregel:
#   Value 2.00: 34.75% error rate
#   Value 1.00: 19.04% error rate
#   Value 0.00: 12.31% error rate
#
# afspraak_controle_verwijzing:
#   Value 2.00: 33.33% error rate
#   Value 1.00: 15.73% error rate
#   Value 0.00: 15.11% error rate
#
# afspraak_galo_gesprek:
#   Value 3.00: 38.46% error rate
#   Value 2.00: 25.79% error rate
#   Value 1.00: 18.01% error rate
#
# afspraak_inspanningsperiode:
#   Value 3.00: 42.31% error rate
#   Value 2.00: 26.51% error rate
#   Value 1.00: 18.89% error rate
#
# afspraak_laatstejaar_aantal_woorden:
#   Value 315.00: 100.00% error rate
#   Value 369.00: 100.00% error rate
#   Value 319.00: 60.00% error rate
#
# afspraak_laatstejaar_resultaat_ingevuld:
#   Value 10.00: 100.00% error rate
#   Value 8.00: 38.24% error rate
#   Value 7.00: 26.56% error rate
#
# afspraak_laatstejaar_resultaat_ingevuld_uniek:
#   Value 6.00: 33.33% error rate
#   Value 5.00: 32.20% error rate
#   Value 4.00: 28.46% error rate
#
# afspraak_resultaat_ingevuld_uniek:
#   Value 9.00: 50.00% error rate
#   Value 7.00: 37.40% error rate
#   Value 6.00: 30.78% error rate
#
# afspraak_voortgangsgesprek:
#   Value 5.00: 66.67% error rate
#   Value 4.00: 20.43% error rate
#   Value 3.00: 17.74% error rate
#
# belemmering_aantal_huidig:
#   Value 8.00: 50.00% error rate
#   Value 5.00: 21.12% error rate
#   Value 6.00: 20.93% error rate
#
# belemmering_dagen_financiele_problemen:
#   Value -11248.00: 100.00% error rate
#   Value -9449.00: 100.00% error rate
#   Value -9292.00: 100.00% error rate
#
# belemmering_dagen_lichamelijke_problematiek:
#   Value -15319.00: 100.00% error rate
#   Value -15233.00: 100.00% error rate
#   Value -15221.00: 100.00% error rate
#
# belemmering_dagen_psychische_problemen:
#   Value -35893.00: 100.00% error rate
#   Value -32015.00: 100.00% error rate
#   Value -32007.00: 100.00% error rate
#
# competentie_aansturen:
#   Value 2.00: 39.62% error rate
#   Value 1.00: 19.20% error rate
#   Value 0.00: 13.53% error rate
#
# competentie_gedrevenheid_en_ambitie_tonen:
#   Value 2.00: 100.00% error rate
#   Value 1.00: 19.57% error rate
#   Value 0.00: 14.42% error rate
#
# competentie_kwaliteit_leveren:
#   Value 2.00: 31.73% error rate
#   Value 1.00: 19.07% error rate
#   Value 0.00: 12.61% error rate
#
# competentie_leren:
#   Value 2.00: 100.00% error rate
#   Value 1.00: 18.94% error rate
#   Value 0.00: 14.61% error rate
#
# competentie_materialen_en_middelen_inzetten:
#   Value 2.00: 34.29% error rate
#   Value 1.00: 19.15% error rate
#   Value 0.00: 13.65% error rate
#
# competentie_met_druk_en_tegenslag_omgaan:
#   Value 2.00: 50.00% error rate
#   Value 1.00: 18.13% error rate
#   Value 0.00: 14.41% error rate
#
# competentie_other:
#   Value 6.00: 33.33% error rate
#   Value 5.00: 22.80% error rate
#   Value 4.00: 20.99% error rate
#
# contacten_onderwerp__werk_intake:
#   Value 4.00: 100.00% error rate
#   Value 3.00: 27.50% error rate
#   Value 2.00: 24.11% error rate
#
# contacten_onderwerp_arbeidsdiagnose_dariuz:
#   Value 2.00: 32.18% error rate
#   Value 1.00: 17.73% error rate
#   Value 0.00: 14.01% error rate
#
# contacten_onderwerp_documenttype__cv_:
#   Value 5.00: 33.33% error rate
#   Value 4.00: 29.25% error rate
#   Value 3.00: 22.79% error rate
#
# contacten_onderwerp_inname_aanvraag:
#   Value 2.00: 100.00% error rate
#   Value 1.00: 19.21% error rate
#   Value 0.00: 14.37% error rate
#
# contacten_onderwerp_inspanningstoets:
#   Value 3.00: 40.00% error rate
#   Value 2.00: 29.79% error rate
#   Value 1.00: 18.76% error rate
#
# contacten_onderwerp_maatregel_overweging:
#   Value 3.00: 65.00% error rate
#   Value 2.00: 23.50% error rate
#   Value 1.00: 17.64% error rate
#
# contacten_onderwerp_matching:
#   Value 16.00: 100.00% error rate
#   Value 17.00: 100.00% error rate
#   Value 15.00: 80.00% error rate
#
# contacten_onderwerp_no_show:
#   Value 5.00: 55.00% error rate
#   Value 4.00: 29.73% error rate
#   Value 3.00: 29.14% error rate
#
# contacten_onderwerp_overige:
#   Value 30.00: 33.33% error rate
#   Value 26.00: 30.43% error rate
#   Value 21.00: 22.88% error rate
#
# contacten_onderwerp_overleg_met_inkomen:
#   Value 5.00: 41.67% error rate
#   Value 4.00: 30.43% error rate
#   Value 3.00: 27.58% error rate
#
# contacten_onderwerp_terugbelverzoek:
#   Value 16.00: 35.71% error rate
#   Value 17.00: 25.00% error rate
#   Value 0.00: 17.48% error rate
#
# contacten_onderwerp_traject:
#   Value 29.00: 33.33% error rate
#   Value 27.00: 25.00% error rate
#   Value 23.00: 20.00% error rate
#
# contacten_onderwerp_uitnodiging:
#   Value 7.00: 66.67% error rate
#   Value 6.00: 27.78% error rate
#   Value 4.00: 23.14% error rate
#
# contacten_onderwerp_ziek__of_afmelding:
#   Value 7.00: 44.44% error rate
#   Value 6.00: 21.74% error rate
#   Value 5.00: 19.35% error rate
#
# contacten_soort_afgelopenjaar_anders:
#   Value 5.00: 41.18% error rate
#   Value 4.00: 31.82% error rate
#   Value 3.00: 27.55% error rate
#
# contacten_soort_afgelopenjaar_document__inkomend_:
#   Value 8.00: 66.67% error rate
#   Value 6.00: 27.10% error rate
#   Value 4.00: 19.23% error rate
#
# contacten_soort_afgelopenjaar_document__uitgaand_:
#   Value 13.00: 41.12% error rate
#   Value 18.00: 33.33% error rate
#   Value 19.00: 33.33% error rate
#
# contacten_soort_afgelopenjaar_e_mail__inkomend_:
#   Value 8.00: 50.00% error rate
#   Value 6.00: 23.89% error rate
#   Value 5.00: 22.80% error rate
#
# contacten_soort_afgelopenjaar_e_mail__uitgaand_:
#   Value 8.00: 38.46% error rate
#   Value 6.00: 31.80% error rate
#   Value 7.00: 30.61% error rate
#
# contacten_soort_afgelopenjaar_gesprek:
#   Value 7.00: 66.67% error rate
#   Value 6.00: 27.50% error rate
#   Value 5.00: 23.40% error rate
#
# contacten_soort_afgelopenjaar_telefoontje__uitgaand_:
#   Value 8.00: 50.00% error rate
#   Value 6.00: 32.26% error rate
#   Value 5.00: 25.63% error rate
#
# contacten_soort_anders:
#   Value 13.00: 50.00% error rate
#   Value 12.00: 30.43% error rate
#   Value 11.00: 26.42% error rate
#
# contacten_soort_document__uitgaand_:
#   Value 92.00: 100.00% error rate
#   Value 104.00: 100.00% error rate
#   Value 73.00: 50.00% error rate
#
# contacten_soort_e_mail__uitgaand_:
#   Value 23.00: 50.00% error rate
#   Value 24.00: 50.00% error rate
#   Value 22.00: 44.44% error rate
#
# contacten_soort_rapportage_deelname:
#   Value 7.00: 31.58% error rate
#   Value 6.00: 22.89% error rate
#   Value 4.00: 19.03% error rate
#
# contacten_soort_telefoontje__uitgaand_:
#   Value 20.00: 33.33% error rate
#   Value 19.00: 25.00% error rate
#   Value 15.00: 19.61% error rate
#
# deelname_act_reintegratieladder_werk_re_integratie:
#   Value 18.00: 100.00% error rate
#   Value 19.00: 66.67% error rate
#   Value 21.00: 50.00% error rate
#
# instrument_aantal_laatstejaar:
#   Value 5.00: 43.75% error rate
#   Value 6.00: 33.33% error rate
#   Value 4.00: 28.04% error rate
#
# instrument_ladder_historie_activering:
#   Value 0.00: 30.10% error rate
#   Value 1.00: 20.10% error rate
#   Value 2.00: 13.79% error rate
#
# instrument_ladder_historie_other:
#   Value 4.00: 50.00% error rate
#   Value 2.00: 19.04% error rate
#   Value 3.00: 17.50% error rate
#
# instrument_ladder_huidig_werk_re_integratie:
#   Value 2.00: 30.48% error rate
#   Value 1.00: 19.58% error rate
#   Value 0.00: 12.61% error rate
#
# instrument_reden_beeindiging_historie_uitval__klant_wz__ziet_af_van_aanbod:
#   Value 2.00: 66.67% error rate
#   Value 1.00: 18.84% error rate
#   Value 0.00: 14.32% error rate
#
# ontheffing_dagen_hist_mean:
#   Value 133.00: 100.00% error rate
#   Value 151.00: 100.00% error rate
#   Value 153.00: 100.00% error rate
#
# ontheffing_dagen_hist_vanwege_uw_medische_omstandigheden:
#   Value 2.00: 100.00% error rate
#   Value 10.00: 100.00% error rate
#   Value 16.00: 100.00% error rate
#
# persoon_leeftijd_bij_onderzoek:
#   Value 19.00: 68.97% error rate
#   Value 21.00: 59.46% error rate
#   Value 66.00: 52.10% error rate
#
# persoonlijke_eigenschappen_dagen_sinds_opvoer:
#   Value 1266.00: 100.00% error rate
#   Value 1270.00: 100.00% error rate
#   Value 1339.00: 100.00% error rate
#
# persoonlijke_eigenschappen_dagen_sinds_taaleis:
#   Value 1267.00: 100.00% error rate
#   Value 1396.00: 100.00% error rate
#   Value 1501.00: 100.00% error rate
#
# pla_einde_doelstelling_bereikt__overdracht:
#   Value 2.00: 42.86% error rate
#   Value 1.00: 16.90% error rate
#   Value 0.00: 14.73% error rate
#
# pla_einde_doelstelling_niet_bereikt__nieuw_trajectplan:
#   Value 7.00: 50.00% error rate
#   Value 0.00: 16.80% error rate
#   Value 1.00: 15.75% error rate
#
# pla_einde_other:
#   Value 2.00: 35.00% error rate
#   Value 1.00: 18.55% error rate
#   Value 0.00: 13.96% error rate
#
# pla_einde_uitstroom_anders_dan_volgen_onderwijs__regulier_werk_of_als_zelfstandige:
#   Value 2.00: 50.00% error rate
#   Value 1.00: 22.46% error rate
#   Value 0.00: 12.96% error rate
#
# pla_hist_pla_categorie_doelstelling_11:
#   Value 2.00: 33.33% error rate
#   Value 1.00: 16.25% error rate
#   Value 0.00: 14.98% error rate
#
# relatie_kind_leeftijd_verschil_ouder_eerste_kind:
#   Value 44.00: 30.43% error rate
#   Value 43.00: 25.76% error rate
#   Value 45.00: 25.00% error rate
#
# relatie_overig_actueel_vorm__kostendeler:
#   Value 5.00: 100.00% error rate
#   Value 4.00: 41.94% error rate
#   Value 3.00: 31.54% error rate
#
# relatie_overig_actueel_vorm__onderhoudsplichtige:
#   Value 2.00: 33.33% error rate
#   Value 1.00: 17.32% error rate
#   Value 0.00: 14.56% error rate
#
# relatie_overig_historie_vorm__andere_inwonende:
#   Value 3.00: 41.18% error rate
#   Value 2.00: 23.63% error rate
#   Value 1.00: 18.19% error rate
#
# relatie_overig_historie_vorm__kostendeler:
#   Value 6.00: 38.89% error rate
#   Value 5.00: 31.03% error rate
#   Value 4.00: 27.73% error rate
#
# relatie_partner_totaal_dagen_partner:
#   Value 67.00: 100.00% error rate
#   Value 1815.00: 100.00% error rate
#   Value 2493.00: 100.00% error rate
#
# typering_dagen_som:
#   Value -10701.00: 100.00% error rate
#   Value -9473.00: 100.00% error rate
#   Value -8635.00: 100.00% error rate
#
# Top 5 Most Important Features:
#   persoonlijke_eigenschappen_nl_spreken2: 1.000
#   adres_aantal_brp_adres: 0.000
#   adres_aantal_verschillende_wijken: 0.000
#   adres_aantal_verzendadres: 0.000
#   adres_aantal_woonadres_handmatig: 0.000
